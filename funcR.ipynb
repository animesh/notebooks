# %%
library(pathview)
# Out:
# Loading required package: org.Hs.eg.db
# Loading required package: AnnotationDbi
# Loading required package: stats4
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, cbind, colnames, do.call,
#     duplicated, eval, evalq, Filter, Find, get, grep, grepl, intersect,
#     is.unsorted, lapply, lengths, Map, mapply, match, mget, order,
#     paste, pmax, pmax.int, pmin, pmin.int, Position, rank, rbind,
#     Reduce, rownames, sapply, setdiff, sort, table, tapply, union,
# ...

# %%
#hda<-read.table("../../promec/Animesh/BERmedianFilteredvalsPathExp.txt",row.names=1, header=T)
#library('readxl')
#hda<-read_xlsx("../../promec/Animesh/Myeloma/MyelomaProjectB1B2combineTTpermcorr.xlsx")
hist(hda$averageLog2diffMMtoMGUS)
#pathview(hda,pathway.id="hsa03410",gene.idtype="symbol")
# Out:
# Plot with title “Histogram of hda$averageLog2diffMMtoMGUS”

# %%
#library(devtools)
#install_github("yunzhang813/FUNNEL-GSEA-R-Package")
library("FUNNEL")
FUNNEL::FUNNEL.GSEA(hda)
# Out:
# Error in checkInputs(X, tt, genesets): argument "genesets" is missing, with no default
# Traceback:
#
# 1. FUNNEL::FUNNEL.GSEA(hda)
# 2. checkInputs(X, tt, genesets)

# %%
#library(imager)
pimg<-load.image("hsa03410.pathview.multi.png")
plot(pimg)
# Out:
# Plot with title “”

# %%
library(ggplot2)
df <- as.data.frame(pimg) 
p <- ggplot(df,aes(x,y))+geom_raster(aes(fill=value))+facet_wrap(~ cc)
p+scale_y_reverse()
# Out:
# plot without title

# %%
bdf <- plyr::mutate(df,channel=factor(cc,labels=c('R','G','B')))
ggplot(bdf,aes(value,col=channel))+geom_histogram(bins=30)+facet_wrap(~ channel)
# Out:
# plot without title
